# %%
import numpy as np

# %%
a = np.array([1.0,5.2,3.6,2.2])
b=a.copy()
b[0]=10
print(b)
print(a)
print(b.base)
# Out:
# [10.   5.2  3.6  2.2]
# [1.  5.2 3.6 2.2]
# None

# %%
c= np.array([4,5,6,8,5,6])
print(c)
c= c.reshape(2,3)
print(c)
print(c.shape)
# Out:
# [4 5 6 8 5 6]
# [[4 5 6]
#  [8 5 6]]
# (2, 3)

# %%
for x in np.nditer(c) :
    print(x)
# Out:
# 4
# 5
# 6
# 8
# 5
# 6

# %%
for x in np.ndenumerate(c) :
    print(x)
# Out:
# ((0, 0), np.int64(4))
# ((0, 1), np.int64(5))
# ((0, 2), np.int64(6))
# ((1, 0), np.int64(8))
# ((1, 1), np.int64(5))
# ((1, 2), np.int64(6))
