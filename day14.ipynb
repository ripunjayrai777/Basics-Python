# %% [markdown]
# Axis :

# %% [markdown]
# axis=0 → column wise

# %% [markdown]
# axis=1 → row wise

# %% [markdown]
# Some Aggregate function are here:

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50, 60])

# %%
print(np.sum(arr))
# Out:
# 210

# %%
print(np.mean(arr))
# Out:
# 35.0

# %% [markdown]
# and more on....
# max, min, std, var, median, argmax, prod, argmin

# %%
print(np.var(arr))
# Out:
# 291.6666666666667

# %%
print(np.argmin(arr))
# Out:
# 0

# %%
print(np.std(arr))
# Out:
# 17.07825127659933

# %%
print(np.prod(arr))
# Out:
# 720000000
