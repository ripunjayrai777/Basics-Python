# %%
import pandas as pd

# %%
a = [10, 20, 30, 40, 50]
myvar = pd.Series(a)
# print(myvar)
print(myvar[2])
# Out:
# 30

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x","y","z"])
# print(myvar)
print(myvar["y"])
# Out:
# 7

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories )
print(myvar)
# print(myvar["day2"])
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
data = {"calories":[420,380,390],
        "duration":[50,40,45]}

# %%
abc = pd.DataFrame(data, index = ["day1", "day2", "day3"])

# %%
print(abc)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(abc.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
pd.options.display.max_rows=999

# %%
df = pd.read_json('data.json')

# %%
print(df.head(5))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        80    110       130     409.1
# 1        60    117       145     479.0
# 2        68    103       135     340.0
# 3        75    109       175     282.4
# 4        40    117       148     406.0

# %%
print(pd.options.display.max_rows)
# Out:
# 999

# %%
pd.options.display.max_rows=60
